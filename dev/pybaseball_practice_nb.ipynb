# %%
import pandas as pd
import pybaseball as pb
import os
import numpy as np
pd.set_option('display.max_columns', 350)

# %%
######### Get Team Performance for a Season ##########

cubs2021_batting = pb.team_game_logs(2021, 'CHC', 'batting')
cubs2021_pitching = pb.team_game_logs(2021, 'CHC', 'pitching')
cubs2021_pitching.columns
# Out:
# Index(['Game', 'Date', 'Home', 'Opp', 'Rslt', 'IP', 'H', 'R', 'ER', 'UER',
#        'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB',
#        'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', 'NumPlayers',
#        'Umpire', 'PitchersUsed'],
#       dtype='object')

# %%
########## Get Statcast Pitching Performance #############
jonlester_game_log = cubs2021_batting.iloc[-2,-1]
jlester = pb.playerid_lookup('lester', 'jon')
# Out:
# Gathering player lookup table. This may take a moment.

# %% [markdown]
# ## Pitcher Statcast ##

# %%
lester_statcast = pb.statcast_pitcher(start_dt='2021-06-24', end_dt='2021-09-27', player_id=jlester['key_mlbam'].values[0])
# Out:
# Gathering Player Data

# %%
lester_statcast
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2021-09-25           87.7           1.94           5.70
# 1            FF  2021-09-25           88.0           1.96           5.62
# 2            FF  2021-09-25           88.1           2.01           5.71
# 3            FC  2021-09-25           87.1           2.01           5.66
# 4            FF  2021-09-25           87.3           2.00           5.60
# ...         ...         ...            ...            ...            ...
# 1442         FF  2021-06-25           89.4           2.66           5.83
# 1443         CU  2021-06-25           72.4           2.72           5.97
# 1444         FC  2021-06-25           84.7           2.74           5.89
# 1445         FF  2021-06-25           89.3           2.57           5.89
# 1446         FF  2021-06-25           88.5           2.58           5.91
#
#       player_name  batter  pitcher     events              description  \
# ...

# %% [markdown]
# ## General Pitching Stats

# %%
data = pb.pitching_stats(2016, 2016)
data.loc[data['Team'] == 'CHC']
# Out:
#      IDfg  Season            Name Team  Age   W   L  WAR   ERA   G  GS  CG  \
# 1    4930    2016      Jon Lester  CHC   32  19   5  4.2  2.44  32  32   2
# 0   12049    2016  Kyle Hendricks  CHC   26  16   8  4.2  2.13  31  30   2
# 12   4153    2016    Jake Arrieta  CHC   30  18   8  3.5  3.10  31  31   1
# 21   1507    2016     John Lackey  CHC   37  11   8  2.9  3.35  29  29   0
# 35   4538    2016    Jason Hammel  CHC   33  15  10  1.3  3.83  30  30   0
#
#     ShO  SV  BS     IP  TBF    H   R  ER  HR  BB  IBB  HBP  WP  BK   SO   GB  \
# 1     0   0   0  202.2  796  154  57  55  21  52    0    6   4   0  197  246
# 0     1   0   0  190.0  745  142  53  45  15  44    3    8   5   0  170  249
# 12    1   0   0  197.1  795  138  72  68  16  76    1    6  16   0  190  272
# 21    0   0   0  188.1  748  146  74  70  23  53    1    9   4   0  180  201
# 35    0   0   0  166.2  692  148  77  71  25  53    0    9   9   0  144  200
#
# ...

# %%
#### Schedule and Record ####
schedule_and_record = pb.schedule_and_record(2016, 'CHC')
schedule_and_record
# Out:
# /Users/samlafell/Documents/Learning/sports_betting_project/Sports_Betting_Env/lib/python3.9/site-packages/pybaseball/team_results.py:70: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('',1) #not a useful column
# /Users/samlafell/Documents/Learning/sports_betting_project/Sports_Betting_Env/lib/python3.9/site-packages/pybaseball/team_results.py:83: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('Streak2',1)
#                   Date   Tm Home_Away  Opp   W/L     R   RA  Inn     W-L  \
# 1        Monday, Apr 4  CHC         @  LAA     W   9.0  0.0  9.0     1-0
# 2       Tuesday, Apr 5  CHC         @  LAA     W   6.0  1.0  9.0     2-0
# 3      Thursday, Apr 7  CHC         @  ARI     W  14.0  6.0  9.0     3-0
# ...

# %%
### Standings ###
data = pb.standings(2016)
data
# Out:
# [                  Tm   W   L  W-L%    GB
#  1     Boston Red Sox  93  69  .574    --
#  2  Baltimore Orioles  89  73  .549   4.0
#  3  Toronto Blue Jays  89  73  .549   4.0
#  4   New York Yankees  84  78  .519   9.0
#  5     Tampa Bay Rays  68  94  .420  25.0,
#                     Tm   W    L  W-L%    GB
#  1   Cleveland Indians  94   67  .584    --
#  2      Detroit Tigers  86   75  .534   8.0
#  3  Kansas City Royals  81   81  .500  13.5
#  4   Chicago White Sox  78   84  .481  16.5
#  5     Minnesota Twins  59  103  .364  35.5,
#                     Tm   W   L  W-L%    GB
#  1       Texas Rangers  95  67  .586    --
#  2    Seattle Mariners  86  76  .531   9.0
#  3      Houston Astros  84  78  .519  11.0
#  4  Los Angeles Angels  74  88  .457  21.0
#  5   Oakland Athletics  69  93  .426  26.0,
#                        Tm   W   L  W-L%    GB
#  1   Washington Nationals  95  67  .586    --
#  2          New York Mets  87  75  .537   8.0
# ...

# %% [markdown]
# # Import the Betting odds

# %%
# Input Data
year = 2017
df2 = pd.read_excel(f'/Users/samlafell/Documents/Learning/sports_betting_project/data/external/mlb_odds_{year}.xlsx')
df2.columns
# Out:
# Index(['Date', 'Rot', 'VH', 'Team', 'Pitcher', '1st', '2nd', '3rd', '4th',
#        '5th', '6th', '7th', '8th', '9th', 'Final', 'Open', 'Close', 'Run Line',
#        'Unnamed: 18', 'Open OU', 'Unnamed: 20', 'Close OU', 'Unnamed: 22'],
#       dtype='object')

# %%
# How many unique games were played?
loop_to = int(df2.shape[0]/2)

# Create a list of these numbers to get Game IDs
lis = list(range(loop_to))

# Two rows per game, repeat each value 2 times
gameid = np.repeat(lis, 2)

# Add as a column
df2['Game_ID'] = gameid

# %%
df2_wide = pd.pivot(df2, index = 'Game_ID', columns = 'VH', values= ['Date', 'Team', 'Final', 'Open', 'Close', 'Run Line', 'Open OU', 'Close OU'])
prefixes = [col[1] for col in df2_wide.columns]
df2_wide = df2_wide.droplevel(1, axis = 1)
df2_wide.columns = prefixes + df2_wide.columns
df2_wide.drop(['VDate', 'VClose OU', 'VOpen OU'], axis = 1, inplace = True)
df2_wide.rename(columns = {'HDate': 'Date',
                 'HOpen OU': 'Open_OU',
                 'HClose OU': 'Close_OU'},
                inplace = True)

df2_wide['Winner'] = np.where(df2_wide['HFinal'] > df2_wide['VFinal'],
                              df2_wide['HTeam'],
                              df2_wide['VTeam'])

df2_wide['OverUnder'] = np.where(df2_wide['HFinal'] + df2_wide['VFinal'] > df2_wide['Close_OU'],
                                 'Over',
                                 np.where(df2_wide['HFinal'] + df2_wide['VFinal'] == df2_wide['Close_OU'],
                                          'Push',
                                          'Under'))

df2_wide['Date'] = df2_wide.Date.astype(str)
df2_wide['Date'] = df2_wide['Date'] + str(year)
df2_wide["Date"] = pd.to_datetime(df2_wide["Date"], format='%m%d%Y')

# %%
interim_data = '/Users/samlafell/Documents/Learning/sports_betting_project/data/interim'
df2_wide.to_csv(os.path.join(interim_data, 'matchups_and_odds.csv'))

# %%
df2_wide
# Out:
#               Date HTeam VTeam HFinal VFinal HOpen VOpen HClose VClose  \
# Game_ID
# 0       2017-04-02   ARI   SFO      6      5   110  -130    129   -144
# 1       2017-04-02   STL   CUB      4      3   105  -125    116   -126
# 2       2017-04-02   TAM   NYY      7      3   100  -120    100   -110
# 3       2017-04-03   WAS   MIA      4      2  -210   180   -215    185
# 4       2017-04-03   NYM   ATL      6      0  -155   135   -183    163
# ...            ...   ...   ...    ...    ...   ...   ...    ...    ...
# 2462    2017-10-25   LOS   HOU      6      7  -113  -107    101   -111
# 2463    2017-10-27   HOU   LOS      5      3  -115  -105   -146    131
# 2464    2017-10-28   HOU   LOS      2      6  -108  -112   -105   -105
# 2465    2017-10-29   HOU   LOS     13     12   120  -140    106   -116
# 2466    2017-10-31   LOS   HOU      3      1  -105  -105   -130    115
#
#         HRun Line VRun Line Open_OU Close_OU Winner OverUnder
# Game_ID
# ...
